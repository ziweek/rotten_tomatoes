# %%
import pandas as pd
import matplotlib.pyplot as plt

df_1 = pd.read_csv('1.csv', index_col='Rank')
df_2 = pd.read_csv('2.csv', index_col='Rank')

# %%
df_1
# Out:
#                                     Unnamed: 0 RatingTomatometer  \
# Rank
# 1.0                       Black Panther (2018)               96%
# 2.0                   Avengers: Endgame (2019)               94%
# 3.0       Mission: Impossible - Fallout (2018)               97%
# 4.0                  Mad Max: Fury Road (2015)               97%
# 5.0   Spider-Man: Into the Spider-Verse (2018)               97%
#
#                                          Title  No. of Reviews  \
# Rank
# 1.0                       Black Panther (2018)             525
# 2.0                   Avengers: Endgame (2019)             547
# 3.0       Mission: Impossible - Fallout (2018)             437
# 4.0                  Mad Max: Fury Road (2015)             434
# 5.0   Spider-Man: Into the Spider-Verse (2018)             393
#
#                                                  Rating  \
# Rank
# 1.0   PG-13 (Sequences of Action Violence|A Brief Ru...
# 2.0   PG-13 (Sequences of Sci-Fi Violence|Action|Som...
# ...

# %%
df_2
# Out:
#                                     Unnamed: 0 RatingTomatometer  \
# Rank
# 1.0                         Toy Story 4 (2019)               97%
# 2.0   Spider-Man: Into the Spider-Verse (2018)               97%
# 3.0                          Inside Out (2015)               98%
# 4.0                                Coco (2017)               97%
# 5.0     Snow White and the Seven Dwarfs (1937)               98%
#
#                                          Title  No. of Reviews  \
# Rank
# 1.0                         Toy Story 4 (2019)             453
# 2.0   Spider-Man: Into the Spider-Verse (2018)             393
# 3.0                          Inside Out (2015)             379
# 4.0                                Coco (2017)             354
# 5.0     Snow White and the Seven Dwarfs (1937)              54
#
#                                                  Rating  \
# Rank
# 1.0                                                   G
# 2.0   PG (Mild Language|Frenetic Action Violence|The...
# ...

# %%
import matplotlib.pyplot as plt

df_2 = df_2.iloc[:4,]

plt.scatter(df_1['RatingTomatometer'],df_1['Box Office (Gross USA)'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df_2['RatingTomatometer'], df_2['Box Office (Gross USA)'])
plt.show()
